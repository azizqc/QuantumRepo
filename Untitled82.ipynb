# %% [markdown]
# <a href="https://colab.research.google.com/github/azizqc/QuantumRepo/blob/main/Untitled82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import matplotlib.pyplot 
import pylatexenc
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister,execute, BasicAer
from qiskit.visualization import plot_histogram
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(5, 'c')
qasm = """
OPENQASM 2.0;
include "qelib1.inc";
gate theta1 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta2 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta3 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta4 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta5 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta6 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta7 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta8 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta9 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta10 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta11 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta12 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta13 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta14 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}

theta1 q[0], q[1];
rz(pi / 2) q[0];

theta2 q[1], q[2];
rz(pi / 2) q[1];

theta3 q[2], q[3];
rz(pi / 2) q[2];

theta4 q[3], q[4];
rz(pi / 2) q[3];
x q[4];


theta8 q[3], q[4];
rz(pi / 2) q[4];
theta7 q[2], q[3];
rz(pi / 2) q[3];
theta6 q[1], q[2];
rz(pi / 2) q[2];
theta5 q[0], q[1];
rz(pi / 2) q[1];
x q[4];

theta11 q[3], q[4];
rz(pi / 2) q[4];
theta10 q[2], q[3];
rz(pi / 2) q[3];
theta9 q[1], q[2];
rz(pi / 2) q[2];
x q[4];

theta13 q[3], q[4];
rz(pi / 2) q[4];
theta12 q[2], q[3];
rz(pi / 2) q[3];
x q[4];

theta14 q[3], q[4];
rz(pi / 2) q[4];

"""
circuit = QuantumCircuit.from_qasm_str(qasm)

circuit.measure(qreg_q[0], creg_c[0])

job = execute(qc, backend = BasicAer.get_backend('qasm_simulator'), shots=1082)
result = job.result()
count = result.get_counts()
plot_histogram(count)
# Out:
# ---------------------------------------------------------------------------
# QasmError                                 Traceback (most recent call last)
# <ipython-input-19-d443b541f99b> in <module>
#     163
#     164 """
# --> 165 circuit = QuantumCircuit.from_qasm_str(qasm)
#     166
#     167 circuit.measure(qreg_q[0], creg_c[0])
#
# /usr/local/lib/python3.9/dist-packages/qiskit/circuit/quantumcircuit.py in from_qasm_str(qasm_str)
#    2495         """
#    2496         qasm = Qasm(data=qasm_str)
# -> 2497         return _circuit_from_qasm(qasm)
#    2498
#    2499     @property
#
# /usr/local/lib/python3.9/dist-packages/qiskit/circuit/quantumcircuit.py in _circuit_from_qasm(qasm)
#    4807     from qiskit.converters import dag_to_circuit
#    4808
# -> 4809     ast = qasm.parse()
#    4810     dag = ast_to_dag(ast)
#    4811     return dag_to_circuit(dag)
#
# /usr/local/lib/python3.9/dist-packages/qiskit/qasm/qasm.py in parse(self)
# ...

# %%
#import matplotlib.pyplot 
import pylatexenc
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister,execute, BasicAer
from qiskit.visualization import plot_histogram
qreg_q = QuantumRegister(5, 'q')
creg_c = ClassicalRegister(5, 'c')
#qasm = 

gate theta1 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta2 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta3 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta4 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta5 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta6 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta7 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta8 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta9 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta10 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta11 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta12 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta13 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}
gate theta14 a, b {
  ry(pi / 2) a;
  cx a, b;
  ry(0) a;
  ry(0) b;
  cx a, b;
  ry(-pi / 2) a;
}


qreg q[5];
creg c[5];

theta1 q[0], q[1];
rz(pi / 2) q[0];

theta2 q[1], q[2];
rz(pi / 2) q[1];

theta3 q[2], q[3];
rz(pi / 2) q[2];

theta4 q[3], q[4];
rz(pi / 2) q[3];
x q[4];


theta8 q[3], q[4];
rz(pi / 2) q[4];
theta7 q[2], q[3];
rz(pi / 2) q[3];
theta6 q[1], q[2];
rz(pi / 2) q[2];
theta5 q[0], q[1];
rz(pi / 2) q[1];
x q[4];

theta11 q[3], q[4];
rz(pi / 2) q[4];
theta10 q[2], q[3];
rz(pi / 2) q[3];
theta9 q[1], q[2];
rz(pi / 2) q[2];
x q[4];

theta13 q[3], q[4];
rz(pi / 2) q[4];
theta12 q[2], q[3];
rz(pi / 2) q[3];
x q[4];

theta14 q[3], q[4];
rz(pi / 2) q[4];


circuit = QuantumCircuit.from_qasm_str(qasm)

circuit.measure_all(2,2)
backend = BasicAer.get_backend('qasm_simulator')
job = execute(circuit, backend, shots=4321)
result = job.result()
count = result.get_counts()
plot_histogram(count)
# Out:
#   File "<ipython-input-6-5720fcc1b241>", line 9
#     gate theta1 a, b {
#          ^
# SyntaxError: invalid syntax

# %%
pip install qiskit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 49.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 77.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 KB 30.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 7.0 MB/s eta 0:00:00
# ...

# %%
pylatexenc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-176b90848f25> in <module>
# ----> 1 pylatexenc
#
# NameError: name 'pylatexenc' is not defined

# %%
from qiskit import QuantumCircuit, execute, BasicAer

backend = BasicAer.get_backend('qasm_simulator')

qc = QuantumCircuit(5, 5)
qc.h(0)
qc.cx(0, range(1, 5))
qc.measure_all()

job = execute(qc, backend, shots=4321)
result = job.result()
count = result.get_counts()
plot_histogram(count)

# %%
pip install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 KB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136831 sha256=fdb5232b8238eb5dcc84f952a7748b476011abaf19dc8a1198641b0aaf074199
#   Stored in directory: /root/.cache/pip/wheels/a3/68/66/2f15abd0673d83c02f354115feedeb89c3daed2ac319b11090
# Successfully built pylatexenc
# ...

# %%
pip install qiskit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 58.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 KB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 14.8 MB/s eta 0:00:00
# ...

# %%
#import matplotlib.pyplot 
import pylatexenc
from numpy import pi
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister,execute, BasicAer
from qiskit.visualization import plot_histogram
#qreg_q = QuantumRegister(5, 'q')
#creg_c = ClassicalRegister(5, 'c')
qc = QuantumCircuit(5, 5)

def theta1(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta2(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta3(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta4(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta5(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta6(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta7(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta8(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta9(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta10(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta11(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta12(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta13(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

def theta14(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(0, a)
  qc.ry(0, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

#qc.qreg(q[5])
#qc.creg(c[5])

theta1(0, 1)
qc.rz(pi / 2, 0);

theta2(1, 2)
qc.rz(pi / 2, 1)

theta3(2, 3)
qc.rz(pi / 2, 2)

theta4(3, 4)
qc.rz(pi / 2, 3)
qc.x(4)


theta8(3, 4)
qc.rz(pi / 2, 4)
theta7(2, 3)
qc.rz(pi / 2, 3)
theta6(1, 2)
qc.rz(pi / 2, 2)
theta5(0, 1)
qc.rz(pi / 2, 1)  
qc.x(4)

theta11(3, 4)
qc.rz(pi / 2,4)
theta10(2, 3)
qc.rz(pi / 2, 3)
theta9(1, 2)
qc.rz(pi / 2,2)
qc.x(4)

theta13(3, 4)
qc.rz(pi / 2,4)
theta12(2, 3)
qc.rz(pi / 2,3)
qc.x(4)

theta14(3, 4)
qc.rz(pi / 2,4)

'''
circuit = QuantumCircuit.from_qasm_str(qasm)

circuit.measure_all(2,2)
backend = BasicAer.get_backend('qasm_simulator')
job = execute(circuit, backend, shots=4321)
result = job.result()
count = result.get_counts()
plot_histogram(count) 
'''
#qc.measure(0, 0)
#qc.measure(1, 1)
#qc.measure(2, 2)
#qc.measure(3, 3)
#qc.measure(4, 4)
#job = execute(qc, backend = BasicAer.get_backend('qasm_simulator'), shots=1024)
#result = job.result()
#count = result.get_counts()
#plot_histogram(count)

qc.draw()
# Out:
#      ┌─────────┐     ┌───────┐     ┌──────────┐┌─────────┐┌─────────┐     »
# q_0: ┤ Ry(π/2) ├──■──┤ Ry(0) ├──■──┤ Ry(-π/2) ├┤ Rz(π/2) ├┤ Ry(π/2) ├─────»
#      └─────────┘┌─┴─┐├───────┤┌─┴─┐├─────────┬┘└─────────┘└┬───────┬┘     »
# q_1: ───────────┤ X ├┤ Ry(0) ├┤ X ├┤ Ry(π/2) ├──────■──────┤ Ry(0) ├───■──»
#                 └───┘└───────┘└───┘└─────────┘    ┌─┴─┐    ├───────┤ ┌─┴─┐»
# q_2: ─────────────────────────────────────────────┤ X ├────┤ Ry(0) ├─┤ X ├»
#                                                   └───┘    └───────┘ └───┘»
# q_3: ─────────────────────────────────────────────────────────────────────»
#                                                                           »
# q_4: ─────────────────────────────────────────────────────────────────────»
#                                                                           »
# c: 5/═════════════════════════════════════════════════════════════════════»
# ...

# %%
import pylatexenc
from numpy import pi
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister,execute, BasicAer
from qiskit.visualization import plot_histogram
#qreg_q = QuantumRegister(5, 'q')
#creg_c = ClassicalRegister(5, 'c')
qc = QuantumCircuit(2, 2)

def theta1(a, b):
  qc.ry(pi / 2, a) 
  qc.cx(a, b)
  qc.ry(pi, a)
  qc.ry(pi, b)
  qc.cx(a, b)
  qc.ry(-pi / 2, a)

theta1(0, 1)
qc.z(0)
#qc.rz(pi / 2, 0);
#qc.draw()
#qc.measure(0,0)
qc.measure(1,1)
job = execute(qc, backend = BasicAer.get_backend('qasm_simulator'), shots=100)
result = job.result()
count = result.get_counts()
plot_histogram(count)
#qc.draw()

# %%
pip install qiskit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 80.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 KB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 5.9 MB/s eta 0:00:00
# ...

# %%
pip install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 KB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136831 sha256=3a54fe5d74ba03f2dd06fcc3e423537e931deebd5e70b24e4e42763005e3ce6d
#   Stored in directory: /root/.cache/pip/wheels/a3/68/66/2f15abd0673d83c02f354115feedeb89c3daed2ac319b11090
# Successfully built pylatexenc
# ...

# %%
qc1= QuantumCircuit(1, 1)
qc1.h(0)
qc1.h(0)
qc.measure(0,0)
job = execute(qc, backend = BasicAer.get_backend('qasm_simulator'), shots=100)
result = job.result()
count = result.get_counts()
plot_histogram(count)
qc1.draw()
# Out:
#      ┌───┐┌───┐
#   q: ┤ H ├┤ H ├
#      └───┘└───┘
# c: 1/══════════
